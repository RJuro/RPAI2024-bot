# %%
from langserve.client import RemoteRunnable

# Initialize the RemoteRunnable with your API 
rag_app = RemoteRunnable("http://127.0.0.1:8000/pirate-speak/")

# call the API with a question
answer = rag_app.invoke("Tell me a joke!")

print(answer)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/langserve/client.py:157, in _raise_for_status(response)
#     156 try:
# --> 157     response.raise_for_status()
#     158 except httpx.HTTPStatusError as e:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_models.py:761, in Response.raise_for_status(self)
#     760 message = message.format(self, error_type=error_type)
# --> 761 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Server error '500 Internal Server Error' for url 'http://127.0.0.1:8000/pirate-speak/invoke'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/500
#
# During handling of the above exception, another exception occurred:
#
# HTTPStatusError                           Traceback (most recent call last)
# /workspaces/RPAI2024-bot/my-app/app/test_endpoint.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell://codespaces%2Bmusical-parakeet-j4w67p6ww59fjgww/workspaces/RPAI2024-bot/my-app/app/test_endpoint.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> rag_app = RemoteRunnable("http://127.0.0.1:8000/pirate-speak/")
#       <a href='vscode-notebook-cell://codespaces%2Bmusical-parakeet-j4w67p6ww59fjgww/workspaces/RPAI2024-bot/my-app/app/test_endpoint.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # call the API with a question
# ----> <a href='vscode-notebook-cell://codespaces%2Bmusical-parakeet-j4w67p6ww59fjgww/workspaces/RPAI2024-bot/my-app/app/test_endpoint.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> answer = rag_app.invoke("Tell me a joke!")
#       <a href='vscode-notebook-cell://codespaces%2Bmusical-parakeet-j4w67p6ww59fjgww/workspaces/RPAI2024-bot/my-app/app/test_endpoint.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> print(answer)
#
# File ~/.python/current/lib/python3.10/site-packages/langserve/client.py:356, in RemoteRunnable.invoke(self, input, config, **kwargs)
#     354 if kwargs:
#     355     raise NotImplementedError("kwargs not implemented yet.")
# --> 356 return self._call_with_config(self._invoke, input, config=config)
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/runnables/base.py:1596, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1592     context = copy_context()
#    1593     context.run(_set_config_context, child_config)
#    1594     output = cast(
#    1595         Output,
# -> 1596         context.run(
#    1597             call_func_with_variable_args,  # type: ignore[arg-type]
#    1598             func,  # type: ignore[arg-type]
#    1599             input,  # type: ignore[arg-type]
#    1600             config,
#    1601             run_manager,
#    1602             **kwargs,
#    1603         ),
#    1604     )
#    1605 except BaseException as e:
#    1606     run_manager.on_chain_error(e)
#
# File ~/.python/current/lib/python3.10/site-packages/langchain_core/runnables/config.py:380, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     378 if run_manager is not None and accepts_run_manager(func):
#     379     kwargs["run_manager"] = run_manager
# --> 380 return func(input, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/langserve/client.py:343, in RemoteRunnable._invoke(self, input, run_manager, config, **kwargs)
#     334 """Invoke the runnable with the given input and config."""
#     335 response = self.sync_client.post(
#     336     "/invoke",
#     337     json={
#    (...)
#     341     },
#     342 )
# --> 343 output, callback_events = _decode_response(
#     344     self._lc_serializer, response, is_batch=False
#     345 )
#     347 if self._use_server_callback_events and callback_events:
#     348     handle_callbacks(run_manager, callback_events)
#
# File ~/.python/current/lib/python3.10/site-packages/langserve/client.py:230, in _decode_response(serializer, response, is_batch)
#     223 def _decode_response(
#     224     serializer: Serializer,
#     225     response: httpx.Response,
#     226     *,
#     227     is_batch: bool = False,
#     228 ) -> Tuple[Any, Union[List[CallbackEventDict], List[List[CallbackEventDict]]]]:
#     229     """Decode the response."""
# --> 230     _raise_for_status(response)
#     231     obj = response.json()
#     232     if not isinstance(obj, dict):
#
# File ~/.python/current/lib/python3.10/site-packages/langserve/client.py:165, in _raise_for_status(response)
#     162 if e.response.text:
#     163     message += f" for {e.response.text}"
# --> 165 raise httpx.HTTPStatusError(
#     166     message=message,
#     167     request=_sanitize_request(e.request),
#     168     response=e.response,
#     169 )
#
# HTTPStatusError: Server error '500 Internal Server Error' for url 'http://127.0.0.1:8000/pirate-speak/invoke'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/500 for Internal Server Error
